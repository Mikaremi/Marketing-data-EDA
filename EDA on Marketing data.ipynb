# %% [markdown]
# # Infomation about the dataset

# %% [markdown]
# This Is The Dataset Of Customers of The Market, containing details about customer aquisitions and purchase history, we'll find some interesting answers using this dataset and make great changes that will be yield in more robust profit for the market.

# %% [markdown]
# description of columns in the dataset
#
# AcceptedCmp1 - 1 if costumer accepted the offer in the 1st campaign, 0 otherwise
#
# AcceptedCmp2 - 1 if costumer accepted the offer in the 2nd campaign, 0 otherwise
#
# AcceptedCmp3 - 1 if costumer accepted the offer in the 3rd campaign, O otherwise
#
# AcceptedCmp4 - 1 if costumer accepted the offer in the 4th campaign, 0 otherwise
#
# AcceptedCmp5 - 1 if costumer accepted the offer in the 5th campaign, 0 otherwise
#
# Response ( target) - 1 if costumer accepted the offer in the last campaign, 0 otherwise
#
# Complain - 1 if costumer complained in the last 2 years
#
# DtCustomer - date of customer's enrollment with the company
#
# Education - customer's level of education
#
# Marital - customer's marital status
#
# Kidhome - number of small children in customer's household
#
# Teenhome - number of teenagers in customer's household
#
# Income - customer's yearly household income
#
# MutFish Products - amount spent on fish products in the last 2 years
#
# MntMeat Products - amount spent on meat products in the last 2 years
#
# Mnt Fruits - amount spent on fruits in the last 2 years
#
# MutSweet Products - amount spent on sweet products in the last 2 years
#
# Mnt Wines - amount spent on wines in the last 2 years
#
# MntGoldProds - amount spent on gold products in the last 2 years
#
# NumDeals Purchases - number of purchases made with discount
#
# NumCatalog Purchases - number of purchases made using catalogue
#
# NumStore Purchases - number of purchases made directly in stores
#
# Num Web Purchases - number of purchases made through company's web site
#
# NumWebVisitsMonth - number of visits to company's web site in the last month
#
# Recency - number of days since the last purchase

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# reading the dataset
marketing_df = pd.read_csv(r'ifood_df.csv')
marketing_df.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...

# %%
marketing_df.columns
# Out:
# Index(['Income', 'Kidhome', 'Teenhome', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
#        'Age', 'Customer_Days', 'marital_Divorced', 'marital_Married',
#        'marital_Single', 'marital_Together', 'marital_Widow',
#        'education_2n Cycle', 'education_Basic', 'education_Graduation',
#        'education_Master', 'education_PhD', 'MntTotal', 'MntRegularProds',
#        'AcceptedCmpOverall'],
#       dtype='object')

# %%
marketing_df.shape
# Out:
# (2205, 39)

# %%
marketing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Income                2205 non-null   float64
#  1   Kidhome               2205 non-null   int64
#  2   Teenhome              2205 non-null   int64
#  3   Recency               2205 non-null   int64
#  4   MntWines              2205 non-null   int64
#  5   MntFruits             2205 non-null   int64
#  6   MntMeatProducts       2205 non-null   int64
#  7   MntFishProducts       2205 non-null   int64
#  8   MntSweetProducts      2205 non-null   int64
#  9   MntGoldProds          2205 non-null   int64
#  10  NumDealsPurchases     2205 non-null   int64
#  11  NumWebPurchases       2205 non-null   int64
#  12  NumCatalogPurchases   2205 non-null   int64
#  13  NumStorePurchases     2205 non-null   int64
#  14  NumWebVisitsMonth     2205 non-null   int64
# ...

# %%
marketing_df.isnull().sum()
# Out:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# education_Master        0
# ...

# %%
marketing_df.describe().T
# Out:
#                        count          mean           std     min      25%  \
# Income                2205.0  51622.094785  20713.063826  1730.0  35196.0
# Kidhome               2205.0      0.442177      0.537132     0.0      0.0
# Teenhome              2205.0      0.506576      0.544380     0.0      0.0
# Recency               2205.0     49.009070     28.932111     0.0     24.0
# MntWines              2205.0    306.164626    337.493839     0.0     24.0
# MntFruits             2205.0     26.403175     39.784484     0.0      2.0
# MntMeatProducts       2205.0    165.312018    217.784507     0.0     16.0
# MntFishProducts       2205.0     37.756463     54.824635     0.0      3.0
# MntSweetProducts      2205.0     27.128345     41.130468     0.0      1.0
# MntGoldProds          2205.0     44.057143     51.736211     0.0      9.0
# NumDealsPurchases     2205.0      2.318367      1.886107     0.0      1.0
# NumWebPurchases       2205.0      4.100680      2.737424     0.0      2.0
# ...

# %%
marketing_df.dtypes
# Out:
# Income                  float64
# Kidhome                   int64
# Teenhome                  int64
# Recency                   int64
# MntWines                  int64
# MntFruits                 int64
# MntMeatProducts           int64
# MntFishProducts           int64
# MntSweetProducts          int64
# MntGoldProds              int64
# NumDealsPurchases         int64
# NumWebPurchases           int64
# NumCatalogPurchases       int64
# NumStorePurchases         int64
# NumWebVisitsMonth         int64
# AcceptedCmp3              int64
# AcceptedCmp4              int64
# AcceptedCmp5              int64
# AcceptedCmp1              int64
# AcceptedCmp2              int64
# Complain                  int64
# Z_CostContact             int64
# Z_Revenue                 int64
# Response                  int64
# Age                       int64
# Customer_Days             int64
# marital_Divorced          int64
# marital_Married           int64
# marital_Single            int64
# ...

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ## average age of company's customers

# %%
avg_age = marketing_df['Age'].mean()
avg_age
# Out:
# 51.09569160997732

# %% [markdown]
# the average age of customers in that company is 51

# %% [markdown]
# ## Age vs customer ratio

# %%
age_df = marketing_df.groupby('Age')[['Age']].count()
age_df
# Out:
#      Age
# Age
# 24     2
# 25     5
# 26     3
# 27     5
# 28    13
# 29    15
# 30    18
# 31    29
# 32    29
# 33    27
# 34    41
# 35    32
# 36    38
# 37    41
# 38    43
# 39    38
# 40    39
# 41    53
# 42    76
# 43    50
# 44    88
# 45    82
# 46    69
# 47    71
# 48    78
# 49    85
# 50    75
# 51    70
# 52    51
# 53    44
# 54    50
# 55    74
# 56    41
# 57    44
# 58    44
# 59    35
# 60    49
# 61    50
# 62    52
# 63    41
# 64    55
# 65    48
# 66    49
# 67    35
# 68    52
# 69    42
# 70    29
# 71    29
# 72    21
# 73    16
# 74    16
# 75     8
# 76     7
# 77     6
# 79     1
# 80     1

# %%
age_graph = plt.figure(figsize=(12,6))
sns.barplot(x=age_df.index,y=age_df.Age)
plt.ylabel('Count')
plt.xticks(rotation = 90);

# %% [markdown]
# ## campaing aquisition

# %%
# how many customers are accepted in campaign 1 as per the total customers
cmpper1 = marketing_df.AcceptedCmp1.sum()/len(marketing_df)*100
cmpper2 = marketing_df.AcceptedCmp2.sum()/len(marketing_df)*100
cmpper3 = marketing_df.AcceptedCmp3.sum()/len(marketing_df)*100
cmpper4 = marketing_df.AcceptedCmp4.sum()/len(marketing_df)*100
cmpper5 = marketing_df.AcceptedCmp5.sum()/len(marketing_df)*100

print('''
Customer Offer Aquisition on campaign 1 is {:.2f}%
Customer Offer Aquisition on campaign 2 is {:.2f}%
Customer Offer Aquisition on campaign 3 is {:.2f}%
Customer Offer Aquisition on campaign 4 is {:.2f}%
Customer Offer Aquisition on campaign 5 is {:.2f}%
'''.format(cmpper1,cmpper2, cmpper3,cmpper4,cmpper5))
# Out:
# Customer Offer Aquisition on campaign 1 is 6.44%
# Customer Offer Aquisition on campaign 2 is 1.36%
# Customer Offer Aquisition on campaign 3 is 7.39%
# Customer Offer Aquisition on campaign 4 is 7.44%
# Customer Offer Aquisition on campaign 5 is 7.30%

# %% [markdown]
# ## average complaint ratio

# %%
complaint_ratio = len(marketing_df['Complain'] == 1)/len(marketing_df)
complaint_ratio
# Out:
# 1.0

# %%
print('complaint ratio of company is {:.2f}%'.format(complaint_ratio*100))
# Out:
# complaint ratio of company is 100.00%

# %% [markdown]
# ## Average purchases on varient outlets and categories

# %%
web_purchases = marketing_df['NumWebPurchases'].mean()
store_purchases = marketing_df['NumStorePurchases'].mean()
catalog_purchases = marketing_df['NumCatalogPurchases'].mean()
discount_purchases = marketing_df['NumDealsPurchases'].mean()

print('''
Average Purchase on website is: {}
Average Purchase on store is: {}
Average Purchase on catalog is: {}
Average Purcahse with discount is: {}
'''.format(web_purchases, store_purchases, catalog_purchases, discount_purchases))
# Out:
# Average Purchase on website is: 4.100680272108844
# Average Purchase on store is: 5.823582766439909
# Average Purchase on catalog is: 2.6453514739229025
# Average Purcahse with discount is: 2.3183673469387753

# %% [markdown]
# ## Avearage recency of purchase

# %%
avg_rec = marketing_df['Recency'].mean()
print('Average purchase day of company is {:.2f}'.format(avg_rec))
# Out:
# Average purchase day of company is 49.01

# %% [markdown]
# ## customer website visit ratio

# %%
visit_web = len(marketing_df[marketing_df['NumWebVisitsMonth']>0])/len(marketing_df)
print('customer website visit percentage  {:.2f}'.format(visit_web*100))
# Out:
# customer website visit percentage  99.73

# %% [markdown]
# # Question: Do they need wheelchair accessibility in the store building?

# %% [markdown]
# ## count senior citizen ration from store customers. Only (senior citizen age is more than 55)

# %%
#narrow it down to the store visitors only
store_customers = marketing_df[marketing_df['NumDealsPurchases']>0]

# %%
# calculate from store customers that are senior citizens
senior_citizens = store_customers[store_customers['Age']>55]

# %%
#calculate an average of senior citizens customers
avg_scc = len(senior_citizens)/len(marketing_df)*100

print('average % of senior citizen customrs is: {:.2f}'.format(avg_scc))
# Out:
# average % of senior citizen customrs is: 34.20

# %% [markdown]
# There is a good number of senior citizens that visit the store, thus it is imparative for there to be a wheelchair accesibility in the company's store

# %% [markdown]
# # Conclusion

# %% [markdown]
# As We have The Data That Shows So Everything We need to make our store and campaings more customer oriented.
#
# We Can Spend On The Highest Usage Outlet
#
# We can close or shortlist the lowest engaged Campaign
#
# We Should Make Changes According To the customers in our store
